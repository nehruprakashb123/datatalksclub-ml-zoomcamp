# %% [markdown]
# Vector Notation

# %% [markdown]
# Vector Multiplication by scalar

# %%
import numpy as np
u = np.array([2,4,5,6])
v = np.array([1,0,0,2])

# %%
np.dot(u, v)
# Out:
# np.int64(14)

# %%
# def matrix_vector_multiplication(U,v):
#     assert U.shape[1] == v.shape[0]

#     num_rows = U.shape[0]
#     result = np.zeros(nums_rows)

#     for i in range(nums_rows):
#         result[i] = np.dot(U[i], v)

#     return result

# %%
np.dot(u, v)
# Out:
# np.int64(14)

# %%
np.dot(u, v)
# Out:
# np.int64(14)
